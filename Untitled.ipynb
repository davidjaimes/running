# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
start_lbs = 183
Ndays = 90
start_date = pd.to_datetime('2020/07/22')

# %%
x = np.array([0, Ndays])
for i in range(1, 4):
    y = start_lbs - (i/7) * x
    plt.plot(x, y, 'C7--')
